-- %%
SELECT * FROM demo_catalog.demo_schema.movie

-- %%
USE CATALOG demo_catalog;
USE SCHEMA demo_schema;
SELECT * FROM movie

-- %%
SELECT current_catalog()

-- %%
SHOW CATALOGS;

-- %%
SELECT current_schema()

-- %%
SHOW SCHEMAS

-- %%
SHOW TABLES

-- %%
%python
spark.sql("SHOW TABLES")

-- %%
%python
display(spark.sql("SHOW TABLES"))

-- %%
%python
df = spark.sql("SELECT * FROM demo_catalog.demo_schema.clients")
display(df)
